# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/DANO_O2/Covid/covid_dataset-unified-w-fed_dist-cleaned.csv')
data
# Out:
#              week       region  \
# 0      2020-04-06       Адыгея
# 1      2020-04-06       Адыгея
# 2      2020-04-06       Адыгея
# 3      2020-04-06       Адыгея
# 4      2020-04-06       Адыгея
# ...           ...          ...
# 75599  2020-10-26  Ярославская
# 75600  2020-10-26  Ярославская
# 75601  2020-10-26  Ярославская
# 75602  2020-10-26  Ярославская
# 75603  2020-10-26  Ярославская
#
#                                                  oced  unemployed  cv_gender  \
# 0                        Производство и строительство          19         18
# 1                        Производство и строительство           2          1
# 2                Финансы, страхование и юриспруденция          13          6
# 3                        Производство и строительство           9          2
# 4      Административная и управленческая деятельность          17          8
# ...                                               ...         ...        ...
# 75599                                          Услуги           2          0
# 75600               Работы, не требующие квалификации          33         20
# 75601                                      Энергетика           1          1
# 75602                    Производство и строительство           1          1
# 75603            Финансы, страхование и юриспруденция          12          1
#
#        cv_birthday_2000  cv_birthday_1990  cv_birthday_1980  cv_birthday_1970  \
# 0                     0                 3                12                19
# 1                     0                 0                 1                 1
# 2                     0                 2                11                13
# 3                     1                 2                 6                 9
# 4                     0                 3                14                17
# ...                 ...               ...               ...               ...
# 75599                 1                 2                 2                 2
# 75600                 2                 9                14                20
# 75601                 0                 0                 1                 1
# 75602                 0                 0                 0                 0
# 75603                 2                 4                 8                 9
#
#        cv_birthday_1960  ...  infections  deaths  healed  tests        Rt  \
# 0                    19  ...        42.0     0.0    44.0    NaN  0.873684
# 1                     2  ...        42.0     0.0    44.0    NaN  0.873684
# 2                    13  ...        42.0     0.0    44.0    NaN  0.873684
# 3                     9  ...        42.0     0.0    44.0    NaN  0.873684
# 4                    17  ...        42.0     0.0    44.0    NaN  0.873684
# ...                 ...  ...         ...     ...     ...    ...       ...
# 75599                 2  ...       770.0     6.0   566.0    NaN  1.111111
# 75600                32  ...       770.0     6.0   566.0    NaN  1.111111
# 75601                 1  ...       770.0     6.0   566.0    NaN  1.111111
# 75602                 1  ...       770.0     6.0   566.0    NaN  1.111111
# 75603                12  ...       770.0     6.0   566.0    NaN  1.111111
#
#        level  yandex_continuous  yandex_level  pass  federal_district
# 0        NaN           3.314286           2.0   0.0               ЮФО
# 1        NaN           3.314286           2.0   0.0               ЮФО
# 2        NaN           3.314286           2.0   0.0               ЮФО
# 3        NaN           3.314286           2.0   0.0               ЮФО
# 4        NaN           3.314286           2.0   0.0               ЮФО
# ...      ...                ...           ...   ...               ...
# 75599    3.0                NaN           NaN   NaN               ЦФО
# 75600    3.0                NaN           NaN   NaN               ЦФО
# 75601    3.0                NaN           NaN   NaN               ЦФО
# 75602    3.0                NaN           NaN   NaN               ЦФО
# 75603    3.0                NaN           NaN   NaN               ЦФО
#
# [75604 rows x 23 columns]

# %% [markdown]
# Посмотрим количество заболеваний по Федеральным Округам

# %%
grouped_data = data.groupby(['week', 'federal_district'])['infections'].sum().reset_index()

unique_oced = grouped_data['federal_district'].unique()

plt.figure(figsize=(12, 8))
for profession in unique_oced:
    profession_data = grouped_data[grouped_data['federal_district'] == profession]
    plt.plot(profession_data['week'], profession_data['infections'], label=profession, marker='o')

plt.title('Общее количество зарегистрированных заболеваний по Федеральным Округам')
plt.xlabel('Неделя')
plt.ylabel('Количество зарегистированных заболеваний')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Явно выделяется СФО, посмотрим на влияние регионов

# %%
feddist_data = data[data['federal_district'] == 'ЦФО']

# %%
grouped_data = feddist_data.groupby(['week', 'region'])['infections'].sum().reset_index()

unique_oced = grouped_data['region'].unique()

plt.figure(figsize=(12, 8))
for profession in unique_oced:
    profession_data = grouped_data[grouped_data['region'] == profession]
    plt.plot(profession_data['week'], profession_data['infections'], label=profession, marker='o')

plt.title('Общее количество зарегистрированных заболеваний по регионам ЦФО')
plt.xlabel('Неделя')
plt.ylabel('Количество зарегистированных заболеваний в регионе')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Явно выделяется Москва.
# Смотрим заболеваемость по Москве и стране (Федеральные округа (ЦФО без Москвы))

# %%
moscow_data = data[data['region'] == 'Москва']

# %%
total_claims = moscow_data.groupby('week')['infections'].sum()

plt.figure(figsize=(10, 6))
plt.plot(total_claims.index, total_claims.values, marker='o', linestyle='-', color='b')
plt.title('Общее количество зарегистрированных заболеваний с течением времени в Москве')
plt.xlabel('Неделя')
plt.ylabel('Количество infections')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
moscow_data = data[data['region'] == 'Москва']
cfo_data = data[data['federal_district'] == 'ЦФО']

total_claims_moscow = moscow_data.groupby('week')['infections'].sum()
total_claims_cfo = cfo_data.groupby('week')['infections'].sum()

plt.figure(figsize=(12, 6))
plt.plot(total_claims_moscow.index, total_claims_moscow.values, marker='o', linestyle='-', color='b', label='Москва')

plt.plot(total_claims_cfo.index, total_claims_cfo.values, marker='o', linestyle='-', color='r', label='ЦФО')

plt.title('Общее количество зарегистрированных заболеваний с течением времени')
plt.xlabel('Неделя')
plt.ylabel('Количество infections')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Количество заболеваний значительно больше чем в остальном ЦФО

# %% [markdown]
# Исключим Москву из ЦФО из выборки
# Почему?
# Исключаем наблюдения по Москве по некоторым причинам (очень выделяется по специфике на фоне остальных регионов):
#
# - более высокий средний доход населения
# - более жесткие меры контроля медицинских ограничений
# - более распространенных тестирований на ковид

# %%
no_moscow_data = data[data['region'] != 'Москва']

# %%
grouped_data = no_moscow_data.groupby(['week', 'federal_district'])['infections'].sum().reset_index()
unique_oced = grouped_data['federal_district'].unique()
plt.figure(figsize=(12, 8))
for profession in unique_oced:
    profession_data = grouped_data[grouped_data['federal_district'] == profession]
    plt.plot(profession_data['week'], profession_data['infections'], label=profession, marker='o')

plt.title('Общее количество зарегистрированных заболеваний по ФО (исключая Москву)')
plt.xlabel('Неделя')
plt.ylabel('Количество зарегистрированных заболеваний')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Теперь гораздо лучше

# %%
no_moscow_file_path = 'dataset_fd_Sp_no-Mos.csv'
no_moscow_data.to_csv(no_moscow_file_path, index=False)

print(f"Данные без строк, где 'region' равно 'Москва', сохранены в файл: {no_moscow_file_path}")
# Out:
# Данные без строк, где 'region' равно 'Москва', сохранены в файл: dataset_fd_Sp_no-Mos.csv

# %%
no_moscow_data
# Out:
#              week       region  \
# 0      2020-04-06       Адыгея
# 1      2020-04-06       Адыгея
# 2      2020-04-06       Адыгея
# 3      2020-04-06       Адыгея
# 4      2020-04-06       Адыгея
# ...           ...          ...
# 75599  2020-10-26  Ярославская
# 75600  2020-10-26  Ярославская
# 75601  2020-10-26  Ярославская
# 75602  2020-10-26  Ярославская
# 75603  2020-10-26  Ярославская
#
#                                                  oced  unemployed  cv_gender  \
# 0                        Производство и строительство          19         18
# 1                        Производство и строительство           2          1
# 2                Финансы, страхование и юриспруденция          13          6
# 3                        Производство и строительство           9          2
# 4      Административная и управленческая деятельность          17          8
# ...                                               ...         ...        ...
# 75599                                          Услуги           2          0
# 75600               Работы, не требующие квалификации          33         20
# 75601                                      Энергетика           1          1
# 75602                    Производство и строительство           1          1
# 75603            Финансы, страхование и юриспруденция          12          1
#
#        cv_birthday_2000  cv_birthday_1990  cv_birthday_1980  cv_birthday_1970  \
# 0                     0                 3                12                19
# 1                     0                 0                 1                 1
# 2                     0                 2                11                13
# 3                     1                 2                 6                 9
# 4                     0                 3                14                17
# ...                 ...               ...               ...               ...
# 75599                 1                 2                 2                 2
# 75600                 2                 9                14                20
# 75601                 0                 0                 1                 1
# 75602                 0                 0                 0                 0
# 75603                 2                 4                 8                 9
#
#        cv_birthday_1960  ...  infections  deaths  healed  tests        Rt  \
# 0                    19  ...        42.0     0.0    44.0    NaN  0.873684
# 1                     2  ...        42.0     0.0    44.0    NaN  0.873684
# 2                    13  ...        42.0     0.0    44.0    NaN  0.873684
# 3                     9  ...        42.0     0.0    44.0    NaN  0.873684
# 4                    17  ...        42.0     0.0    44.0    NaN  0.873684
# ...                 ...  ...         ...     ...     ...    ...       ...
# 75599                 2  ...       770.0     6.0   566.0    NaN  1.111111
# 75600                32  ...       770.0     6.0   566.0    NaN  1.111111
# 75601                 1  ...       770.0     6.0   566.0    NaN  1.111111
# 75602                 1  ...       770.0     6.0   566.0    NaN  1.111111
# 75603                12  ...       770.0     6.0   566.0    NaN  1.111111
#
#        level  yandex_continuous  yandex_level  pass  federal_district
# 0        NaN           3.314286           2.0   0.0               ЮФО
# 1        NaN           3.314286           2.0   0.0               ЮФО
# 2        NaN           3.314286           2.0   0.0               ЮФО
# 3        NaN           3.314286           2.0   0.0               ЮФО
# 4        NaN           3.314286           2.0   0.0               ЮФО
# ...      ...                ...           ...   ...               ...
# 75599    3.0                NaN           NaN   NaN               ЦФО
# 75600    3.0                NaN           NaN   NaN               ЦФО
# 75601    3.0                NaN           NaN   NaN               ЦФО
# 75602    3.0                NaN           NaN   NaN               ЦФО
# 75603    3.0                NaN           NaN   NaN               ЦФО
#
# [74632 rows x 23 columns]
