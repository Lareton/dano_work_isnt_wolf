# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('dataset_1.csv')
data
# Out:
#              week       region  \
# 0      2020-04-06       Адыгея
# 1      2020-04-06       Адыгея
# 2      2020-04-06       Адыгея
# 3      2020-04-06       Адыгея
# 4      2020-04-06       Адыгея
# ...           ...          ...
# 75599  2020-10-26  Ярославская
# 75600  2020-10-26  Ярославская
# 75601  2020-10-26  Ярославская
# 75602  2020-10-26  Ярославская
# 75603  2020-10-26  Ярославская
#
#                                                     oced  unemployed  \
# 0      Строительство, ремонт, стройматериалы, недвижи...          19
# 1                                         Машиностроение           2
# 2                                          Юриспруденция          13
# 3                                 Пищевая промышленность           9
# 4      Государственная служба, некоммерческие организ...          17
# ...                                                  ...         ...
# 75599           Услуги населению, сервисное обслуживание           2
# ...

# %%
column_name = 'oced'

unique_values = data[column_name].unique()

print(unique_values)

value_counts = data[column_name].value_counts()

print(value_counts)
# Out:
# ['Строительство, ремонт, стройматериалы, недвижимость' 'Машиностроение'
#  'Юриспруденция' 'Пищевая промышленность'
#  'Государственная служба, некоммерческие организации'
#  'Безопасность, службы охраны' 'Продажи, закупки, снабжение, торговля'
#  'Образование, наука' 'Информационные технологии, телекоммуникации, связь'
#  'Искусство, культура и развлечения'
#  'Финансы, кредит, страхование, пенсионное обеспечение'
#  'Туризм, гостиницы, рестораны' 'Кадровая служба, управление персоналом'
#  'Административная работа, секретариат, АХО' 'Производство'
#  'Лесная, деревообрабатывающая, целлюлозно-бумажная промышленность' 'None'
#  'Добывающая промышленность'
#  'Здравоохранение, спорт, красота, социальное обеспечение'
#  'Химическая, нефтехимическая, топливная промышленность'
#  'Сельское хозяйство, экология, ветеринария'
#  'Транспорт, автобизнес, логистика, склад, ВЭД'
#  'Услуги населению, сервисное обслуживание' 'Домашний персонал'
# ...

# %% [markdown]
# Разбив на Сферы деятельности

# %%
import pandas as pd


category_mapping = {
    'None': 'Работы, не требующие квалификации',
    'Работы, не требующие квалификации': 'Работы, не требующие квалификации',

    'Продажи, закупки, снабжение, торговля': 'Торговля и продажи',
    'Административная работа, секретариат, АХО': 'Административная и управленческая деятельность',
    'Государственная служба, некоммерческие организации': 'Административная и управленческая деятельность',
    'Транспорт, автобизнес, логистика, склад, ВЭД': 'Транспорт и логистика',
    'Рабочие специальности': 'Производство и строительство',
    'Финансы, кредит, страхование, пенсионное обеспечение': 'Финансы, страхование и юриспруденция',

    'Здравоохранение, спорт, красота, социальное обеспечение': 'Здравоохранение и социальное обеспечение',
    'Строительство, ремонт, стройматериалы, недвижимость': 'Производство и строительство',
    'Образование, наука': 'Образование',
    'Безопасность, службы охраны' : 'Услуги',
    'Пищевая промышленность': 'Производство и строительство',
    'Информационные технологии, телекоммуникации, связь': 'Связь',
    'Производство': 'Производство и строительство',
    'Юриспруденция': 'Финансы, страхование и юриспруденция',
    'ЖКХ, эксплуатация': 'Административная и управленческая деятельность',


    'Кадровая служба, управление персоналом': 'Административная и управленческая деятельность',

    'Искусство, культура и развлечения': 'Услуги',
    'Услуги населению, сервисное обслуживание': 'Услуги',
    'Туризм, гостиницы, рестораны': 'Услуги',
    'Сельское хозяйство, экология, ветеринария': 'Здравоохранение и социальное обеспечение',
    'Высший менеджмент': 'Административная и управленческая деятельность',
    'Маркетинг, реклама, PR': 'Торговля и продажи',
    'Легкая промышленность': 'Производство и строительство',
    'Машиностроение': 'Производство и строительство',
    'Электроэнергетика' : 'Энергетика',
    'Домашний персонал': 'Услуги',
    'Добывающая промышленность': 'Производство и строительство',
    'Металлургия, металлообработка': 'Производство и строительство',
    'Лесная, деревообрабатывающая, целлюлозно-бумажная промышленность': 'Производство и строительство',
    'Химическая, нефтехимическая, топливная промышленность': 'Производство и строительство',
    'Консалтинг, стратегическое развитие, управление': 'Административная и управленческая деятельность',
    #'Начало трудовой деятельности': 'Работы, не требующие квалификации',
    #'Логистика': 'Транспорт и логистика',
}

data['oced'] = data['oced'].map(category_mapping)
print(data)
# Out:
#              week       region  \
# 0      2020-04-06       Адыгея
# 1      2020-04-06       Адыгея
# 2      2020-04-06       Адыгея
# 3      2020-04-06       Адыгея
# 4      2020-04-06       Адыгея
# ...           ...          ...
# 75599  2020-10-26  Ярославская
# 75600  2020-10-26  Ярославская
# 75601  2020-10-26  Ярославская
# 75602  2020-10-26  Ярославская
# 75603  2020-10-26  Ярославская
#
#                                                  oced  unemployed  cv_gender  \
# 0                        Производство и строительство          19         18
# 1                        Производство и строительство           2          1
# 2                Финансы, страхование и юриспруденция          13          6
# 3                        Производство и строительство           9          2
# 4      Административная и управленческая деятельность          17          8
# ...                                               ...         ...        ...
# ...

# %%
unique_oced = data['oced'].unique()

print("Уникальные значения в столбце 'oced':")
print(unique_oced)
# Out:
# Уникальные значения в столбце 'oced':
# ['Производство и строительство' 'Финансы, страхование и юриспруденция'
#  'Административная и управленческая деятельность' 'Услуги'
#  'Торговля и продажи' 'Образование' 'Связь'
#  'Работы, не требующие квалификации'
#  'Здравоохранение и социальное обеспечение' 'Транспорт и логистика'
#  'Энергетика']

# %%
data.head()
# Out:
#          week  region                                            oced  \
# 0  2020-04-06  Адыгея                    Производство и строительство
# 1  2020-04-06  Адыгея                    Производство и строительство
# 2  2020-04-06  Адыгея            Финансы, страхование и юриспруденция
# 3  2020-04-06  Адыгея                    Производство и строительство
# 4  2020-04-06  Адыгея  Административная и управленческая деятельность
#
#    unemployed  cv_gender  cv_birthday_2000  cv_birthday_1990  \
# 0          19         18                 0                 3
# 1           2          1                 0                 0
# 2          13          6                 0                 2
# 3           9          2                 1                 2
# 4          17          8                 0                 3
#
#    cv_birthday_1980  cv_birthday_1970  cv_birthday_1960  ...     women  \
# 0                12                19                19  ...  245928.0
# ...

# %% [markdown]
# Разбив на ФедОкруги

# %%
region_to_federal_district = {
    'Белгородская': 'ЦФО',
    'Брянская': 'ЦФО',
    'Владимирская': 'ЦФО',
    'Воронежская': 'ЦФО',
    'Ивановская': 'ЦФО',
    'Калужская': 'ЦФО',
    'Костромская': 'ЦФО',
    'Курская': 'ЦФО',
    'Липецкая': 'ЦФО',
    'Московская': 'ЦФО',
    'Орловская': 'ЦФО',
    'Рязанская': 'ЦФО',
    'Смоленская': 'ЦФО',
    'Тамбовская': 'ЦФО',
    'Тверская': 'ЦФО',
    'Тульская': 'ЦФО',
    'Ярославская': 'ЦФО',
    'Москва': 'ЦФО',
    ####
    'Карелия': 'СЗФО',
    'Коми': 'СЗФО',
    'Архангельская': 'СЗФО',
    'Вологодская': 'СЗФО',
    'Калининградская': 'СЗФО',
    'Ленинградская': 'СЗФО',
    'Мурманская': 'СЗФО',
    'Новгородская': 'СЗФО',
    'Псковская': 'СЗФО',
    'Санкт-Петербург': 'СЗФО',
    #'Ненецкий АО': 'СЗФО',

    ######
    'Дагестан': 'СКФО',
    'Ингушетия': 'СКФО',
    'Кабардино-Балкария': 'СКФО',
    'Карачаево-Черкессия': 'СКФО',
    'Северная Осетия': 'СКФО',
    'Чечня': 'СКФО',
    'Ставропольский край': 'СКФО',
    ######
    'Башкортостан': 'ПФО',
    'Марий Эл': 'ПФО',
    'Мордовия': 'ПФО',
    'Татарстан': 'ПФО',
    'Удмуртия': 'ПФО',
    'Чувашия': 'ПФО',
    'Пермский край': 'ПФО',
    'Кировская': 'ПФО',
    'Нижегородская': 'ПФО',
    'Оренбургская': 'ПФО',
    'Пензенская': 'ПФО',
    'Самарская': 'ПФО',
    'Саратовская': 'ПФО',
    'Ульяновская': 'ПФО',
    ####
    'Курганская': 'УФО',
    'Свердловская': 'УФО',
    'Тюменская': 'УФО',
    'Челябинская': 'УФО',
    'ХМАО': 'УФО',
    'Ямало-Ненецкий АО': 'УФО',
    ####
    'Алтай': 'СФО',
    'Тыва': 'СФО',
    'Хакасия': 'СФО',
    'Алтайский край': 'СФО',
    'Красноярский край': 'СФО',
    'Иркутская': 'СФО',
    'Кемеровская': 'СФО',
    'Новосибирская': 'СФО',
    'Омская': 'СФО',
    'Томская': 'СФО',
    ####
    'Бурятия': 'ДФО',
    'Саха': 'ДФО',
    'Забайкальский край': 'ДФО',
    'Камчатский край': 'ДФО',
    'Приморский край': 'ДФО',
    'Хабаровский край': 'ДФО',
    'Амурская': 'ДФО',
    'Магаданская': 'ДФО',
    'Сахалинская': 'ДФО',
    'Еврейская АО': 'ДФО',
    #'Чукотский АО': 'ДФО',
    ####
    'Адыгея': 'ЮФО',
    'Калмыкия': 'ЮФО',
    'Крым': 'ЮФО',
    'Краснодарский край': 'ЮФО',
    'Астраханская': 'ЮФО',
    'Волгоградская': 'ЮФО',
    'Ростовская': 'ЮФО',
    'Севастополь': 'ЮФО',
    ###
    #'Байконур': 'Байконур'

}

data['federal_district'] = data['region'].map(region_to_federal_district)

print(data[['region', 'federal_district']])
# Out:
#             region federal_district
# 0           Адыгея              ЮФО
# 1           Адыгея              ЮФО
# 2           Адыгея              ЮФО
# 3           Адыгея              ЮФО
# 4           Адыгея              ЮФО
# ...            ...              ...
# 75599  Ярославская              ЦФО
# 75600  Ярославская              ЦФО
# 75601  Ярославская              ЦФО
# 75602  Ярославская              ЦФО
# 75603  Ярославская              ЦФО
#
# [75604 rows x 2 columns]

# %%
unique_districts = data['federal_district'].unique()

print("Уникальные значения в столбце 'Федеральный округ':")
print(unique_districts)
# Out:
# Уникальные значения в столбце 'Федеральный округ':
# ['ЮФО' 'СФО' 'ДФО' 'СЗФО' 'ПФО' 'ЦФО' 'СКФО' 'УФО']

# %%
regions_with_nan_district = data.loc[data['federal_district'].isna(), 'region']


print("Значения в столбце 'region', где 'Федеральный округ' равен nan:")
print(regions_with_nan_district)
# Out:
# Значения в столбце 'region', где 'Федеральный округ' равен nan:
# Series([], Name: region, dtype: object)

# %%
new_file_path = 'covid_dataset-unified-w-fed_dist-cleaned.csv'
data.to_csv(new_file_path, index=False)
print(f"Данные сохранены в файл: {new_file_path}")
# Out:
# Данные сохранены в файл: /content/drive/MyDrive/DANO_O2/Covid/covid_dataset-unified-w-fed_dist-cleaned.csv
